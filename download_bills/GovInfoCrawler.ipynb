# %% [markdown]
# This notebook crawls through the GovInfo website (operated by the U.S Government Publishing Office). The crawler downloads and extracts all bill full-texts, summaries, and bill statuses for the U.S. Congress that are available on GovInfo, which is currently the 113th through the 118th Congress, inclusive. The notebook should take under 20 minutes to run.

# %%
import requests
import json
import os
import zipfile

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept': 'application/json'
}
s = requests.Session()
s.headers.update(headers)

bills = s.get('https://www.govinfo.gov/bulkdata/json/BILLS/')
congresses = bills.json()['files']

for congress in congresses:
    if not congress['name'].isnumeric():
        continue  # Skip folders like /resources/
    print('Getting', congress['name'])
    response = s.get(congress['link'])
    sessions = response.json()['files']

    for session in sessions:
        print('Getting', session['name'])
        response = s.get(session['link'])
        bill_types = response.json()['files']

        for bill_type in bill_types:
            print('Getting', bill_type['name'])
            response = s.get(bill_type['link'])
            bills = response.json()['files']

            for bill in bills:
                if bill['mimeType'] == 'application/zip':
                    dest_dir = f"./data/bills/{congress['name']}/{session['name']}/{bill_type['name']}/"
                    os.makedirs(dest_dir, exist_ok=True)
                    response = requests.get(bill['link'])
                    if response.status_code == 200:
                        with open(dest_dir + bill['name'], 'wb') as f:
                            f.write(response.content)
                    else:
                        print(f"Failed to download. HTTP Status Code: {response.status_code}")
# Out:
# Getting 118
# Getting 1
# Getting sres
# Getting hres
# Getting hconres
# Getting hr
# Getting hjres
# Getting s
# Getting sjres
# Getting sconres
# Getting 117
# Getting 2
# Getting s
# Getting sconres
# Getting sres
# Getting hr
# Getting hres
# Getting hjres
# Getting sjres
# Getting hconres
# Getting 1
# Getting sconres
# Getting sres
# Getting hres
# Getting hr
# Getting hjres
# Getting hconres
# Getting s
# Getting sjres
# Getting 116
# Getting 2
# Getting hr
# Getting hres
# Getting hjres
# Getting sjres
# Getting s
# Getting sres
# Getting sconres
# Getting hconres
# Getting 1
# Getting hres
# Getting sres
# Getting sjres
# Getting hconres
# Getting hjres
# Getting hr
# Getting s
# Getting sconres
# Getting 115
# Getting 2
# Getting s
# Getting hconres
# Getting hjres
# Getting hr
# Getting sres
# Getting hres
# Getting sconres
# Getting sjres
# Getting 1
# Getting sconres
# Getting hconres
# Getting hjres
# Getting hres
# Getting hr
# Getting sres
# Getting s
# Getting sjres
# Getting 114
# Getting 2
# Getting hr
# Getting s
# Getting hres
# Getting hconres
# Getting sres
# Getting hjres
# Getting sjres
# Getting sconres
# Getting 1
# Getting hr
# Getting hconres
# Getting sres
# Getting hres
# Getting sconres
# Getting hjres
# Getting s
# Getting sjres
# Getting 113
# Getting 2
# Getting hjres
# Getting hr
# Getting hres
# Getting s
# Getting hconres
# Getting sjres
# Getting sconres
# Getting sres
# Getting 1
# Getting sconres
# Getting hjres
# Getting hr
# Getting hconres
# Getting hres
# Getting s
# Getting sres
# Getting sjres

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept': 'application/json'
}
s = requests.Session()
s.headers.update(headers)

statuses = s.get('https://www.govinfo.gov/bulkdata/json/BILLSTATUS/')
congresses = statuses.json()['files']

for congress in congresses:
    if not congress['name'].isnumeric():
        continue
    print('Getting', congress['name'])
    response = s.get(congress['link'])
    bill_types = response.json()['files']

    for bill_type in bill_types:
        print('Getting', bill_type['name'])
        response = s.get(bill_type['link'])
        statuses = response.json()['files']

        for status in statuses:
            if status['mimeType'] == 'application/zip':
                dest_dir = f"./data/BILLSTATUS/{congress['name']}/{bill_type['name']}/"
                os.makedirs(dest_dir, exist_ok=True)
                response = requests.get(status['link'])
                if response.status_code == 200:
                    with open(dest_dir + status['name'], 'wb') as f:
                        f.write(response.content)
                else:
                    print(f"Failed to download. HTTP Status Code: {response.status_code}")
# Out:
# Getting 118
# Getting sres
# Getting hr
# Getting hconres
# Getting hjres
# Getting hres
# Getting s
# Getting sjres
# Getting sconres
# Getting 117
# Getting sconres
# Getting s
# Getting sres
# Getting hres
# Getting hconres
# Getting hjres
# Getting hr
# Getting sjres
# Getting 116
# Getting hconres
# Getting hres
# Getting hjres
# Getting sjres
# Getting hr
# Getting sres
# Getting s
# Getting sconres
# Getting 115
# Getting sres
# Getting sconres
# Getting sjres
# Getting hres
# Getting s
# Getting hconres
# Getting hjres
# Getting hr
# Getting 114
# Getting sres
# Getting hconres
# Getting sconres
# Getting hres
# Getting hr
# Getting s
# Getting sjres
# Getting hjres
# Getting 113
# Getting s
# Getting hjres
# Getting hconres
# Getting hres
# Getting sconres
# Getting sjres
# Getting sres
# Getting hr
# Getting 112
# Getting hconres
# Getting hres
# Getting hr
# Getting hjres
# Getting sres
# Getting s
# Getting sjres
# Getting sconres
# Getting 111
# Getting hres
# Getting s
# Getting hr
# Getting sres
# Getting hjres
# Getting sconres
# Getting hconres
# Getting sjres
# Getting 110
# Getting hr
# Getting sres
# Getting hres
# Getting s
# Getting hjres
# Getting sjres
# Getting sconres
# Getting hconres
# Getting 109
# Getting hconres
# Getting hres
# Getting hr
# Getting sconres
# Getting hjres
# Getting sres
# Getting s
# Getting sjres
# Getting 108
# Getting hr
# Getting s
# Getting hconres
# Getting hres
# Getting sconres
# Getting hjres
# Getting sres
# Getting sjres

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept': 'application/json'
}
s = requests.Session()
s.headers.update(headers)

summaries = s.get('https://www.govinfo.gov/bulkdata/json/BILLSUM/')
congresses = summaries.json()['files']

for congress in congresses:
    if not congress['name'].isnumeric():
        continue
    print('Getting', congress['name'])
    response = s.get(congress['link'])
    bill_types = response.json()['files']

    for bill_type in bill_types:
        print('Getting', bill_type['name'])
        response = s.get(bill_type['link'])
        summaries = response.json()['files']

        for summary in summaries:
            if summary['mimeType'] == 'application/zip':
                dest_dir = f"./data/billsummaries/{congress['name']}/{bill_type['name']}/"
                os.makedirs(dest_dir, exist_ok=True)
                response = requests.get(summary['link'])
                if response.status_code == 200:
                    with open(dest_dir + summary['name'], 'wb') as f:
                        f.write(response.content)
                else:
                    print(f"Failed to download. HTTP Status Code: {response.status_code}")
# Out:
# Getting 118
# Getting sres
# Getting hjres
# Getting hr
# Getting hconres
# Getting hres
# Getting sjres
# Getting s
# Getting sconres
# Getting 117
# Getting hr
# Getting hjres
# Getting hres
# Getting sres
# Getting hconres
# Getting s
# Getting sconres
# Getting sjres
# Getting 116
# Getting hr
# Getting hres
# Getting hjres
# Getting hconres
# Getting sjres
# Getting sres
# Getting s
# Getting sconres
# Getting 115
# Getting hres
# Getting s
# Getting hr
# Getting hconres
# Getting hjres
# Getting sconres
# Getting sjres
# Getting sres
# Getting 114
# Getting hr
# Getting s
# Getting hconres
# Getting hres
# Getting hjres
# Getting sconres
# Getting sres
# Getting sjres
# Getting 113
# Getting hconres
# Getting hres
# Getting hjres
# Getting hr
# Getting sconres
# Getting s
# Getting sjres
# Getting sres

# %%
def unzip_all_in_directory(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".zip"):
                zip_path = os.path.join(root, file)
                extract_to = root

                with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                    zip_ref.extractall(extract_to)
                print(f"Extracted: {zip_path}")

# %%
unzip_all_in_directory('./data')
# Out:
# Extracted: ./data\bills\113\1\hconres\BILLS-113-1-hconres.zip
# Extracted: ./data\bills\113\1\hjres\BILLS-113-1-hjres.zip
# Extracted: ./data\bills\113\1\hr\BILLS-113-1-hr.zip
# Extracted: ./data\bills\113\1\hres\BILLS-113-1-hres.zip
# Extracted: ./data\bills\113\1\s\BILLS-113-1-s.zip
# Extracted: ./data\bills\113\1\sconres\BILLS-113-1-sconres.zip
# Extracted: ./data\bills\113\1\sjres\BILLS-113-1-sjres.zip
# Extracted: ./data\bills\113\1\sres\BILLS-113-1-sres.zip
# Extracted: ./data\bills\113\2\hconres\BILLS-113-2-hconres.zip
# Extracted: ./data\bills\113\2\hjres\BILLS-113-2-hjres.zip
# Extracted: ./data\bills\113\2\hr\BILLS-113-2-hr.zip
# Extracted: ./data\bills\113\2\hres\BILLS-113-2-hres.zip
# Extracted: ./data\bills\113\2\s\BILLS-113-2-s.zip
# Extracted: ./data\bills\113\2\sconres\BILLS-113-2-sconres.zip
# Extracted: ./data\bills\113\2\sjres\BILLS-113-2-sjres.zip
# Extracted: ./data\bills\113\2\sres\BILLS-113-2-sres.zip
# Extracted: ./data\bills\114\1\hconres\BILLS-114-1-hconres.zip
# Extracted: ./data\bills\114\1\hjres\BILLS-114-1-hjres.zip
# Extracted: ./data\bills\114\1\hr\BILLS-114-1-hr.zip
# Extracted: ./data\bills\114\1\hres\BILLS-114-1-hres.zip
# Extracted: ./data\bills\114\1\s\BILLS-114-1-s.zip
# Extracted: ./data\bills\114\1\sconres\BILLS-114-1-sconres.zip
# Extracted: ./data\bills\114\1\sjres\BILLS-114-1-sjres.zip
# Extracted: ./data\bills\114\1\sres\BILLS-114-1-sres.zip
# Extracted: ./data\bills\114\2\hconres\BILLS-114-2-hconres.zip
# Extracted: ./data\bills\114\2\hjres\BILLS-114-2-hjres.zip
# Extracted: ./data\bills\114\2\hr\BILLS-114-2-hr.zip
# Extracted: ./data\bills\114\2\hres\BILLS-114-2-hres.zip
# Extracted: ./data\bills\114\2\s\BILLS-114-2-s.zip
# Extracted: ./data\bills\114\2\sconres\BILLS-114-2-sconres.zip
# Extracted: ./data\bills\114\2\sjres\BILLS-114-2-sjres.zip
# Extracted: ./data\bills\114\2\sres\BILLS-114-2-sres.zip
# Extracted: ./data\bills\115\1\hconres\BILLS-115-1-hconres.zip
# Extracted: ./data\bills\115\1\hjres\BILLS-115-1-hjres.zip
# Extracted: ./data\bills\115\1\hr\BILLS-115-1-hr.zip
# Extracted: ./data\bills\115\1\hres\BILLS-115-1-hres.zip
# Extracted: ./data\bills\115\1\s\BILLS-115-1-s.zip
# Extracted: ./data\bills\115\1\sconres\BILLS-115-1-sconres.zip
# Extracted: ./data\bills\115\1\sjres\BILLS-115-1-sjres.zip
# Extracted: ./data\bills\115\1\sres\BILLS-115-1-sres.zip
# Extracted: ./data\bills\115\2\hconres\BILLS-115-2-hconres.zip
# Extracted: ./data\bills\115\2\hjres\BILLS-115-2-hjres.zip
# Extracted: ./data\bills\115\2\hr\BILLS-115-2-hr.zip
# Extracted: ./data\bills\115\2\hres\BILLS-115-2-hres.zip
# Extracted: ./data\bills\115\2\s\BILLS-115-2-s.zip
# Extracted: ./data\bills\115\2\sconres\BILLS-115-2-sconres.zip
# Extracted: ./data\bills\115\2\sjres\BILLS-115-2-sjres.zip
# Extracted: ./data\bills\115\2\sres\BILLS-115-2-sres.zip
# Extracted: ./data\bills\116\1\hconres\BILLS-116-1-hconres.zip
# Extracted: ./data\bills\116\1\hjres\BILLS-116-1-hjres.zip
# Extracted: ./data\bills\116\1\hr\BILLS-116-1-hr.zip
# Extracted: ./data\bills\116\1\hres\BILLS-116-1-hres.zip
# Extracted: ./data\bills\116\1\s\BILLS-116-1-s.zip
# Extracted: ./data\bills\116\1\sconres\BILLS-116-1-sconres.zip
# Extracted: ./data\bills\116\1\sjres\BILLS-116-1-sjres.zip
# Extracted: ./data\bills\116\1\sres\BILLS-116-1-sres.zip
# Extracted: ./data\bills\116\2\hconres\BILLS-116-2-hconres.zip
# Extracted: ./data\bills\116\2\hjres\BILLS-116-2-hjres.zip
# Extracted: ./data\bills\116\2\hr\BILLS-116-2-hr.zip
# Extracted: ./data\bills\116\2\hres\BILLS-116-2-hres.zip
# Extracted: ./data\bills\116\2\s\BILLS-116-2-s.zip
# Extracted: ./data\bills\116\2\sconres\BILLS-116-2-sconres.zip
# Extracted: ./data\bills\116\2\sjres\BILLS-116-2-sjres.zip
# Extracted: ./data\bills\116\2\sres\BILLS-116-2-sres.zip
# Extracted: ./data\bills\117\1\hconres\BILLS-117-1-hconres.zip
# Extracted: ./data\bills\117\1\hjres\BILLS-117-1-hjres.zip
# Extracted: ./data\bills\117\1\hr\BILLS-117-1-hr.zip
# Extracted: ./data\bills\117\1\hres\BILLS-117-1-hres.zip
# Extracted: ./data\bills\117\1\s\BILLS-117-1-s.zip
# Extracted: ./data\bills\117\1\sconres\BILLS-117-1-sconres.zip
# Extracted: ./data\bills\117\1\sjres\BILLS-117-1-sjres.zip
# Extracted: ./data\bills\117\1\sres\BILLS-117-1-sres.zip
# Extracted: ./data\bills\117\2\hconres\BILLS-117-2-hconres.zip
# Extracted: ./data\bills\117\2\hjres\BILLS-117-2-hjres.zip
# Extracted: ./data\bills\117\2\hr\BILLS-117-2-hr.zip
# Extracted: ./data\bills\117\2\hres\BILLS-117-2-hres.zip
# Extracted: ./data\bills\117\2\s\BILLS-117-2-s.zip
# Extracted: ./data\bills\117\2\sconres\BILLS-117-2-sconres.zip
# Extracted: ./data\bills\117\2\sjres\BILLS-117-2-sjres.zip
# Extracted: ./data\bills\117\2\sres\BILLS-117-2-sres.zip
# Extracted: ./data\bills\118\1\hconres\BILLS-118-1-hconres.zip
# Extracted: ./data\bills\118\1\hjres\BILLS-118-1-hjres.zip
# Extracted: ./data\bills\118\1\hr\BILLS-118-1-hr.zip
# Extracted: ./data\bills\118\1\hres\BILLS-118-1-hres.zip
# Extracted: ./data\bills\118\1\s\BILLS-118-1-s.zip
# Extracted: ./data\bills\118\1\sconres\BILLS-118-1-sconres.zip
# Extracted: ./data\bills\118\1\sjres\BILLS-118-1-sjres.zip
# Extracted: ./data\bills\118\1\sres\BILLS-118-1-sres.zip
# Extracted: ./data\BILLSTATUS\108\hconres\BILLSTATUS-108-hconres.zip
# Extracted: ./data\BILLSTATUS\108\hjres\BILLSTATUS-108-hjres.zip
# Extracted: ./data\BILLSTATUS\108\hr\BILLSTATUS-108-hr.zip
# Extracted: ./data\BILLSTATUS\108\hres\BILLSTATUS-108-hres.zip
# Extracted: ./data\BILLSTATUS\108\s\BILLSTATUS-108-s.zip
# Extracted: ./data\BILLSTATUS\108\sconres\BILLSTATUS-108-sconres.zip
# Extracted: ./data\BILLSTATUS\108\sjres\BILLSTATUS-108-sjres.zip
# Extracted: ./data\BILLSTATUS\108\sres\BILLSTATUS-108-sres.zip
# Extracted: ./data\BILLSTATUS\109\hconres\BILLSTATUS-109-hconres.zip
# Extracted: ./data\BILLSTATUS\109\hjres\BILLSTATUS-109-hjres.zip
# Extracted: ./data\BILLSTATUS\109\hr\BILLSTATUS-109-hr.zip
# Extracted: ./data\BILLSTATUS\109\hres\BILLSTATUS-109-hres.zip
# Extracted: ./data\BILLSTATUS\109\s\BILLSTATUS-109-s.zip
# Extracted: ./data\BILLSTATUS\109\sconres\BILLSTATUS-109-sconres.zip
# Extracted: ./data\BILLSTATUS\109\sjres\BILLSTATUS-109-sjres.zip
# Extracted: ./data\BILLSTATUS\109\sres\BILLSTATUS-109-sres.zip
# Extracted: ./data\BILLSTATUS\110\hconres\BILLSTATUS-110-hconres.zip
# Extracted: ./data\BILLSTATUS\110\hjres\BILLSTATUS-110-hjres.zip
# Extracted: ./data\BILLSTATUS\110\hr\BILLSTATUS-110-hr.zip
# Extracted: ./data\BILLSTATUS\110\hres\BILLSTATUS-110-hres.zip
# Extracted: ./data\BILLSTATUS\110\s\BILLSTATUS-110-s.zip
# Extracted: ./data\BILLSTATUS\110\sconres\BILLSTATUS-110-sconres.zip
# Extracted: ./data\BILLSTATUS\110\sjres\BILLSTATUS-110-sjres.zip
# Extracted: ./data\BILLSTATUS\110\sres\BILLSTATUS-110-sres.zip
# Extracted: ./data\BILLSTATUS\111\hconres\BILLSTATUS-111-hconres.zip
# Extracted: ./data\BILLSTATUS\111\hjres\BILLSTATUS-111-hjres.zip
# Extracted: ./data\BILLSTATUS\111\hr\BILLSTATUS-111-hr.zip
# Extracted: ./data\BILLSTATUS\111\hres\BILLSTATUS-111-hres.zip
# Extracted: ./data\BILLSTATUS\111\s\BILLSTATUS-111-s.zip
# Extracted: ./data\BILLSTATUS\111\sconres\BILLSTATUS-111-sconres.zip
# Extracted: ./data\BILLSTATUS\111\sjres\BILLSTATUS-111-sjres.zip
# Extracted: ./data\BILLSTATUS\111\sres\BILLSTATUS-111-sres.zip
# Extracted: ./data\BILLSTATUS\112\hconres\BILLSTATUS-112-hconres.zip
# Extracted: ./data\BILLSTATUS\112\hjres\BILLSTATUS-112-hjres.zip
# Extracted: ./data\BILLSTATUS\112\hr\BILLSTATUS-112-hr.zip
# Extracted: ./data\BILLSTATUS\112\hres\BILLSTATUS-112-hres.zip
# Extracted: ./data\BILLSTATUS\112\s\BILLSTATUS-112-s.zip
# Extracted: ./data\BILLSTATUS\112\sconres\BILLSTATUS-112-sconres.zip
# Extracted: ./data\BILLSTATUS\112\sjres\BILLSTATUS-112-sjres.zip
# Extracted: ./data\BILLSTATUS\112\sres\BILLSTATUS-112-sres.zip
# Extracted: ./data\BILLSTATUS\113\hconres\BILLSTATUS-113-hconres.zip
# Extracted: ./data\BILLSTATUS\113\hjres\BILLSTATUS-113-hjres.zip
# Extracted: ./data\BILLSTATUS\113\hr\BILLSTATUS-113-hr.zip
# Extracted: ./data\BILLSTATUS\113\hres\BILLSTATUS-113-hres.zip
# Extracted: ./data\BILLSTATUS\113\s\BILLSTATUS-113-s.zip
# Extracted: ./data\BILLSTATUS\113\sconres\BILLSTATUS-113-sconres.zip
# Extracted: ./data\BILLSTATUS\113\sjres\BILLSTATUS-113-sjres.zip
# Extracted: ./data\BILLSTATUS\113\sres\BILLSTATUS-113-sres.zip
# Extracted: ./data\BILLSTATUS\114\hconres\BILLSTATUS-114-hconres.zip
# Extracted: ./data\BILLSTATUS\114\hjres\BILLSTATUS-114-hjres.zip
# Extracted: ./data\BILLSTATUS\114\hr\BILLSTATUS-114-hr.zip
# Extracted: ./data\BILLSTATUS\114\hres\BILLSTATUS-114-hres.zip
# Extracted: ./data\BILLSTATUS\114\s\BILLSTATUS-114-s.zip
# Extracted: ./data\BILLSTATUS\114\sconres\BILLSTATUS-114-sconres.zip
# Extracted: ./data\BILLSTATUS\114\sjres\BILLSTATUS-114-sjres.zip
# Extracted: ./data\BILLSTATUS\114\sres\BILLSTATUS-114-sres.zip
# Extracted: ./data\BILLSTATUS\115\hconres\BILLSTATUS-115-hconres.zip
# Extracted: ./data\BILLSTATUS\115\hjres\BILLSTATUS-115-hjres.zip
# Extracted: ./data\BILLSTATUS\115\hr\BILLSTATUS-115-hr.zip
# Extracted: ./data\BILLSTATUS\115\hres\BILLSTATUS-115-hres.zip
# Extracted: ./data\BILLSTATUS\115\s\BILLSTATUS-115-s.zip
# Extracted: ./data\BILLSTATUS\115\sconres\BILLSTATUS-115-sconres.zip
# Extracted: ./data\BILLSTATUS\115\sjres\BILLSTATUS-115-sjres.zip
# Extracted: ./data\BILLSTATUS\115\sres\BILLSTATUS-115-sres.zip
# Extracted: ./data\BILLSTATUS\116\hconres\BILLSTATUS-116-hconres.zip
# Extracted: ./data\BILLSTATUS\116\hjres\BILLSTATUS-116-hjres.zip
# Extracted: ./data\BILLSTATUS\116\hr\BILLSTATUS-116-hr.zip
# Extracted: ./data\BILLSTATUS\116\hres\BILLSTATUS-116-hres.zip
# Extracted: ./data\BILLSTATUS\116\s\BILLSTATUS-116-s.zip
# Extracted: ./data\BILLSTATUS\116\sconres\BILLSTATUS-116-sconres.zip
# Extracted: ./data\BILLSTATUS\116\sjres\BILLSTATUS-116-sjres.zip
# Extracted: ./data\BILLSTATUS\116\sres\BILLSTATUS-116-sres.zip
# Extracted: ./data\BILLSTATUS\117\hconres\BILLSTATUS-117-hconres.zip
# Extracted: ./data\BILLSTATUS\117\hjres\BILLSTATUS-117-hjres.zip
# Extracted: ./data\BILLSTATUS\117\hr\BILLSTATUS-117-hr.zip
# Extracted: ./data\BILLSTATUS\117\hres\BILLSTATUS-117-hres.zip
# Extracted: ./data\BILLSTATUS\117\s\BILLSTATUS-117-s.zip
# Extracted: ./data\BILLSTATUS\117\sconres\BILLSTATUS-117-sconres.zip
# Extracted: ./data\BILLSTATUS\117\sjres\BILLSTATUS-117-sjres.zip
# Extracted: ./data\BILLSTATUS\117\sres\BILLSTATUS-117-sres.zip
# Extracted: ./data\BILLSTATUS\118\hconres\BILLSTATUS-118-hconres.zip
# Extracted: ./data\BILLSTATUS\118\hjres\BILLSTATUS-118-hjres.zip
# Extracted: ./data\BILLSTATUS\118\hr\BILLSTATUS-118-hr.zip
# Extracted: ./data\BILLSTATUS\118\hres\BILLSTATUS-118-hres.zip
# Extracted: ./data\BILLSTATUS\118\s\BILLSTATUS-118-s.zip
# Extracted: ./data\BILLSTATUS\118\sconres\BILLSTATUS-118-sconres.zip
# Extracted: ./data\BILLSTATUS\118\sjres\BILLSTATUS-118-sjres.zip
# Extracted: ./data\BILLSTATUS\118\sres\BILLSTATUS-118-sres.zip
# Extracted: ./data\billsummaries\113\hconres\BILLSUM-113-hconres.zip
# Extracted: ./data\billsummaries\113\hjres\BILLSUM-113-hjres.zip
# Extracted: ./data\billsummaries\113\hr\BILLSUM-113-hr.zip
# Extracted: ./data\billsummaries\113\hres\BILLSUM-113-hres.zip
# Extracted: ./data\billsummaries\113\s\BILLSUM-113-s.zip
# Extracted: ./data\billsummaries\113\sconres\BILLSUM-113-sconres.zip
# Extracted: ./data\billsummaries\113\sjres\BILLSUM-113-sjres.zip
# Extracted: ./data\billsummaries\113\sres\BILLSUM-113-sres.zip
# Extracted: ./data\billsummaries\114\hconres\BILLSUM-114-hconres.zip
# Extracted: ./data\billsummaries\114\hjres\BILLSUM-114-hjres.zip
# Extracted: ./data\billsummaries\114\hr\BILLSUM-114-hr.zip
# Extracted: ./data\billsummaries\114\hres\BILLSUM-114-hres.zip
# Extracted: ./data\billsummaries\114\s\BILLSUM-114-s.zip
# Extracted: ./data\billsummaries\114\sconres\BILLSUM-114-sconres.zip
# Extracted: ./data\billsummaries\114\sjres\BILLSUM-114-sjres.zip
# Extracted: ./data\billsummaries\114\sres\BILLSUM-114-sres.zip
# Extracted: ./data\billsummaries\115\hconres\BILLSUM-115-hconres.zip
# Extracted: ./data\billsummaries\115\hjres\BILLSUM-115-hjres.zip
# Extracted: ./data\billsummaries\115\hr\BILLSUM-115-hr.zip
# Extracted: ./data\billsummaries\115\hres\BILLSUM-115-hres.zip
# Extracted: ./data\billsummaries\115\s\BILLSUM-115-s.zip
# Extracted: ./data\billsummaries\115\sconres\BILLSUM-115-sconres.zip
# Extracted: ./data\billsummaries\115\sjres\BILLSUM-115-sjres.zip
# Extracted: ./data\billsummaries\115\sres\BILLSUM-115-sres.zip
# Extracted: ./data\billsummaries\116\hconres\BILLSUM-116-hconres.zip
# Extracted: ./data\billsummaries\116\hjres\BILLSUM-116-hjres.zip
# Extracted: ./data\billsummaries\116\hr\BILLSUM-116-hr.zip
# Extracted: ./data\billsummaries\116\hres\BILLSUM-116-hres.zip
# Extracted: ./data\billsummaries\116\s\BILLSUM-116-s.zip
# Extracted: ./data\billsummaries\116\sconres\BILLSUM-116-sconres.zip
# Extracted: ./data\billsummaries\116\sjres\BILLSUM-116-sjres.zip
# Extracted: ./data\billsummaries\116\sres\BILLSUM-116-sres.zip
# Extracted: ./data\billsummaries\117\hconres\BILLSUM-117-hconres.zip
# Extracted: ./data\billsummaries\117\hjres\BILLSUM-117-hjres.zip
# Extracted: ./data\billsummaries\117\hr\BILLSUM-117-hr.zip
# Extracted: ./data\billsummaries\117\hres\BILLSUM-117-hres.zip
# Extracted: ./data\billsummaries\117\s\BILLSUM-117-s.zip
# Extracted: ./data\billsummaries\117\sconres\BILLSUM-117-sconres.zip
# Extracted: ./data\billsummaries\117\sjres\BILLSUM-117-sjres.zip
# Extracted: ./data\billsummaries\117\sres\BILLSUM-117-sres.zip
# Extracted: ./data\billsummaries\118\hconres\BILLSUM-118-hconres.zip
# Extracted: ./data\billsummaries\118\hjres\BILLSUM-118-hjres.zip
# Extracted: ./data\billsummaries\118\hr\BILLSUM-118-hr.zip
# Extracted: ./data\billsummaries\118\hres\BILLSUM-118-hres.zip
# Extracted: ./data\billsummaries\118\s\BILLSUM-118-s.zip
# Extracted: ./data\billsummaries\118\sconres\BILLSUM-118-sconres.zip
# Extracted: ./data\billsummaries\118\sjres\BILLSUM-118-sjres.zip
# Extracted: ./data\billsummaries\118\sres\BILLSUM-118-sres.zip

# %%
def delete_zip_files(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.zip'):
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Deleted {file_path}")

delete_zip_files('./data')
# Out:
# Deleted ./data\bills\113\1\hconres\BILLS-113-1-hconres.zip
# Deleted ./data\bills\113\1\hjres\BILLS-113-1-hjres.zip
# Deleted ./data\bills\113\1\hr\BILLS-113-1-hr.zip
# Deleted ./data\bills\113\1\hres\BILLS-113-1-hres.zip
# Deleted ./data\bills\113\1\s\BILLS-113-1-s.zip
# Deleted ./data\bills\113\1\sconres\BILLS-113-1-sconres.zip
# Deleted ./data\bills\113\1\sjres\BILLS-113-1-sjres.zip
# Deleted ./data\bills\113\1\sres\BILLS-113-1-sres.zip
# Deleted ./data\bills\113\2\hconres\BILLS-113-2-hconres.zip
# Deleted ./data\bills\113\2\hjres\BILLS-113-2-hjres.zip
# Deleted ./data\bills\113\2\hr\BILLS-113-2-hr.zip
# Deleted ./data\bills\113\2\hres\BILLS-113-2-hres.zip
# Deleted ./data\bills\113\2\s\BILLS-113-2-s.zip
# Deleted ./data\bills\113\2\sconres\BILLS-113-2-sconres.zip
# Deleted ./data\bills\113\2\sjres\BILLS-113-2-sjres.zip
# Deleted ./data\bills\113\2\sres\BILLS-113-2-sres.zip
# Deleted ./data\bills\114\1\hconres\BILLS-114-1-hconres.zip
# Deleted ./data\bills\114\1\hjres\BILLS-114-1-hjres.zip
# Deleted ./data\bills\114\1\hr\BILLS-114-1-hr.zip
# Deleted ./data\bills\114\1\hres\BILLS-114-1-hres.zip
# Deleted ./data\bills\114\1\s\BILLS-114-1-s.zip
# Deleted ./data\bills\114\1\sconres\BILLS-114-1-sconres.zip
# Deleted ./data\bills\114\1\sjres\BILLS-114-1-sjres.zip
# Deleted ./data\bills\114\1\sres\BILLS-114-1-sres.zip
# Deleted ./data\bills\114\2\hconres\BILLS-114-2-hconres.zip
# Deleted ./data\bills\114\2\hjres\BILLS-114-2-hjres.zip
# Deleted ./data\bills\114\2\hr\BILLS-114-2-hr.zip
# Deleted ./data\bills\114\2\hres\BILLS-114-2-hres.zip
# Deleted ./data\bills\114\2\s\BILLS-114-2-s.zip
# Deleted ./data\bills\114\2\sconres\BILLS-114-2-sconres.zip
# Deleted ./data\bills\114\2\sjres\BILLS-114-2-sjres.zip
# Deleted ./data\bills\114\2\sres\BILLS-114-2-sres.zip
# Deleted ./data\bills\115\1\hconres\BILLS-115-1-hconres.zip
# Deleted ./data\bills\115\1\hjres\BILLS-115-1-hjres.zip
# Deleted ./data\bills\115\1\hr\BILLS-115-1-hr.zip
# Deleted ./data\bills\115\1\hres\BILLS-115-1-hres.zip
# Deleted ./data\bills\115\1\s\BILLS-115-1-s.zip
# Deleted ./data\bills\115\1\sconres\BILLS-115-1-sconres.zip
# Deleted ./data\bills\115\1\sjres\BILLS-115-1-sjres.zip
# Deleted ./data\bills\115\1\sres\BILLS-115-1-sres.zip
# Deleted ./data\bills\115\2\hconres\BILLS-115-2-hconres.zip
# Deleted ./data\bills\115\2\hjres\BILLS-115-2-hjres.zip
# Deleted ./data\bills\115\2\hr\BILLS-115-2-hr.zip
# Deleted ./data\bills\115\2\hres\BILLS-115-2-hres.zip
# Deleted ./data\bills\115\2\s\BILLS-115-2-s.zip
# Deleted ./data\bills\115\2\sconres\BILLS-115-2-sconres.zip
# Deleted ./data\bills\115\2\sjres\BILLS-115-2-sjres.zip
# Deleted ./data\bills\115\2\sres\BILLS-115-2-sres.zip
# Deleted ./data\bills\116\1\hconres\BILLS-116-1-hconres.zip
# Deleted ./data\bills\116\1\hjres\BILLS-116-1-hjres.zip
# Deleted ./data\bills\116\1\hr\BILLS-116-1-hr.zip
# Deleted ./data\bills\116\1\hres\BILLS-116-1-hres.zip
# Deleted ./data\bills\116\1\s\BILLS-116-1-s.zip
# Deleted ./data\bills\116\1\sconres\BILLS-116-1-sconres.zip
# Deleted ./data\bills\116\1\sjres\BILLS-116-1-sjres.zip
# Deleted ./data\bills\116\1\sres\BILLS-116-1-sres.zip
# Deleted ./data\bills\116\2\hconres\BILLS-116-2-hconres.zip
# Deleted ./data\bills\116\2\hjres\BILLS-116-2-hjres.zip
# Deleted ./data\bills\116\2\hr\BILLS-116-2-hr.zip
# Deleted ./data\bills\116\2\hres\BILLS-116-2-hres.zip
# Deleted ./data\bills\116\2\s\BILLS-116-2-s.zip
# Deleted ./data\bills\116\2\sconres\BILLS-116-2-sconres.zip
# Deleted ./data\bills\116\2\sjres\BILLS-116-2-sjres.zip
# Deleted ./data\bills\116\2\sres\BILLS-116-2-sres.zip
# Deleted ./data\bills\117\1\hconres\BILLS-117-1-hconres.zip
# Deleted ./data\bills\117\1\hjres\BILLS-117-1-hjres.zip
# Deleted ./data\bills\117\1\hr\BILLS-117-1-hr.zip
# Deleted ./data\bills\117\1\hres\BILLS-117-1-hres.zip
# Deleted ./data\bills\117\1\s\BILLS-117-1-s.zip
# Deleted ./data\bills\117\1\sconres\BILLS-117-1-sconres.zip
# Deleted ./data\bills\117\1\sjres\BILLS-117-1-sjres.zip
# Deleted ./data\bills\117\1\sres\BILLS-117-1-sres.zip
# Deleted ./data\bills\117\2\hconres\BILLS-117-2-hconres.zip
# Deleted ./data\bills\117\2\hjres\BILLS-117-2-hjres.zip
# Deleted ./data\bills\117\2\hr\BILLS-117-2-hr.zip
# Deleted ./data\bills\117\2\hres\BILLS-117-2-hres.zip
# Deleted ./data\bills\117\2\s\BILLS-117-2-s.zip
# Deleted ./data\bills\117\2\sconres\BILLS-117-2-sconres.zip
# Deleted ./data\bills\117\2\sjres\BILLS-117-2-sjres.zip
# Deleted ./data\bills\117\2\sres\BILLS-117-2-sres.zip
# Deleted ./data\bills\118\1\hconres\BILLS-118-1-hconres.zip
# Deleted ./data\bills\118\1\hjres\BILLS-118-1-hjres.zip
# Deleted ./data\bills\118\1\hr\BILLS-118-1-hr.zip
# Deleted ./data\bills\118\1\hres\BILLS-118-1-hres.zip
# Deleted ./data\bills\118\1\s\BILLS-118-1-s.zip
# Deleted ./data\bills\118\1\sconres\BILLS-118-1-sconres.zip
# Deleted ./data\bills\118\1\sjres\BILLS-118-1-sjres.zip
# Deleted ./data\bills\118\1\sres\BILLS-118-1-sres.zip
# Deleted ./data\BILLSTATUS\108\hconres\BILLSTATUS-108-hconres.zip
# Deleted ./data\BILLSTATUS\108\hjres\BILLSTATUS-108-hjres.zip
# Deleted ./data\BILLSTATUS\108\hr\BILLSTATUS-108-hr.zip
# Deleted ./data\BILLSTATUS\108\hres\BILLSTATUS-108-hres.zip
# Deleted ./data\BILLSTATUS\108\s\BILLSTATUS-108-s.zip
# Deleted ./data\BILLSTATUS\108\sconres\BILLSTATUS-108-sconres.zip
# Deleted ./data\BILLSTATUS\108\sjres\BILLSTATUS-108-sjres.zip
# Deleted ./data\BILLSTATUS\108\sres\BILLSTATUS-108-sres.zip
# Deleted ./data\BILLSTATUS\109\hconres\BILLSTATUS-109-hconres.zip
# Deleted ./data\BILLSTATUS\109\hjres\BILLSTATUS-109-hjres.zip
# Deleted ./data\BILLSTATUS\109\hr\BILLSTATUS-109-hr.zip
# Deleted ./data\BILLSTATUS\109\hres\BILLSTATUS-109-hres.zip
# Deleted ./data\BILLSTATUS\109\s\BILLSTATUS-109-s.zip
# Deleted ./data\BILLSTATUS\109\sconres\BILLSTATUS-109-sconres.zip
# Deleted ./data\BILLSTATUS\109\sjres\BILLSTATUS-109-sjres.zip
# Deleted ./data\BILLSTATUS\109\sres\BILLSTATUS-109-sres.zip
# Deleted ./data\BILLSTATUS\110\hconres\BILLSTATUS-110-hconres.zip
# Deleted ./data\BILLSTATUS\110\hjres\BILLSTATUS-110-hjres.zip
# Deleted ./data\BILLSTATUS\110\hr\BILLSTATUS-110-hr.zip
# Deleted ./data\BILLSTATUS\110\hres\BILLSTATUS-110-hres.zip
# Deleted ./data\BILLSTATUS\110\s\BILLSTATUS-110-s.zip
# Deleted ./data\BILLSTATUS\110\sconres\BILLSTATUS-110-sconres.zip
# Deleted ./data\BILLSTATUS\110\sjres\BILLSTATUS-110-sjres.zip
# Deleted ./data\BILLSTATUS\110\sres\BILLSTATUS-110-sres.zip
# Deleted ./data\BILLSTATUS\111\hconres\BILLSTATUS-111-hconres.zip
# Deleted ./data\BILLSTATUS\111\hjres\BILLSTATUS-111-hjres.zip
# Deleted ./data\BILLSTATUS\111\hr\BILLSTATUS-111-hr.zip
# Deleted ./data\BILLSTATUS\111\hres\BILLSTATUS-111-hres.zip
# Deleted ./data\BILLSTATUS\111\s\BILLSTATUS-111-s.zip
# Deleted ./data\BILLSTATUS\111\sconres\BILLSTATUS-111-sconres.zip
# Deleted ./data\BILLSTATUS\111\sjres\BILLSTATUS-111-sjres.zip
# Deleted ./data\BILLSTATUS\111\sres\BILLSTATUS-111-sres.zip
# Deleted ./data\BILLSTATUS\112\hconres\BILLSTATUS-112-hconres.zip
# Deleted ./data\BILLSTATUS\112\hjres\BILLSTATUS-112-hjres.zip
# Deleted ./data\BILLSTATUS\112\hr\BILLSTATUS-112-hr.zip
# Deleted ./data\BILLSTATUS\112\hres\BILLSTATUS-112-hres.zip
# Deleted ./data\BILLSTATUS\112\s\BILLSTATUS-112-s.zip
# Deleted ./data\BILLSTATUS\112\sconres\BILLSTATUS-112-sconres.zip
# Deleted ./data\BILLSTATUS\112\sjres\BILLSTATUS-112-sjres.zip
# Deleted ./data\BILLSTATUS\112\sres\BILLSTATUS-112-sres.zip
# Deleted ./data\BILLSTATUS\113\hconres\BILLSTATUS-113-hconres.zip
# Deleted ./data\BILLSTATUS\113\hjres\BILLSTATUS-113-hjres.zip
# Deleted ./data\BILLSTATUS\113\hr\BILLSTATUS-113-hr.zip
# Deleted ./data\BILLSTATUS\113\hres\BILLSTATUS-113-hres.zip
# Deleted ./data\BILLSTATUS\113\s\BILLSTATUS-113-s.zip
# Deleted ./data\BILLSTATUS\113\sconres\BILLSTATUS-113-sconres.zip
# Deleted ./data\BILLSTATUS\113\sjres\BILLSTATUS-113-sjres.zip
# Deleted ./data\BILLSTATUS\113\sres\BILLSTATUS-113-sres.zip
# Deleted ./data\BILLSTATUS\114\hconres\BILLSTATUS-114-hconres.zip
# Deleted ./data\BILLSTATUS\114\hjres\BILLSTATUS-114-hjres.zip
# Deleted ./data\BILLSTATUS\114\hr\BILLSTATUS-114-hr.zip
# Deleted ./data\BILLSTATUS\114\hres\BILLSTATUS-114-hres.zip
# Deleted ./data\BILLSTATUS\114\s\BILLSTATUS-114-s.zip
# Deleted ./data\BILLSTATUS\114\sconres\BILLSTATUS-114-sconres.zip
# Deleted ./data\BILLSTATUS\114\sjres\BILLSTATUS-114-sjres.zip
# Deleted ./data\BILLSTATUS\114\sres\BILLSTATUS-114-sres.zip
# Deleted ./data\BILLSTATUS\115\hconres\BILLSTATUS-115-hconres.zip
# Deleted ./data\BILLSTATUS\115\hjres\BILLSTATUS-115-hjres.zip
# Deleted ./data\BILLSTATUS\115\hr\BILLSTATUS-115-hr.zip
# Deleted ./data\BILLSTATUS\115\hres\BILLSTATUS-115-hres.zip
# Deleted ./data\BILLSTATUS\115\s\BILLSTATUS-115-s.zip
# Deleted ./data\BILLSTATUS\115\sconres\BILLSTATUS-115-sconres.zip
# Deleted ./data\BILLSTATUS\115\sjres\BILLSTATUS-115-sjres.zip
# Deleted ./data\BILLSTATUS\115\sres\BILLSTATUS-115-sres.zip
# Deleted ./data\BILLSTATUS\116\hconres\BILLSTATUS-116-hconres.zip
# Deleted ./data\BILLSTATUS\116\hjres\BILLSTATUS-116-hjres.zip
# Deleted ./data\BILLSTATUS\116\hr\BILLSTATUS-116-hr.zip
# Deleted ./data\BILLSTATUS\116\hres\BILLSTATUS-116-hres.zip
# Deleted ./data\BILLSTATUS\116\s\BILLSTATUS-116-s.zip
# Deleted ./data\BILLSTATUS\116\sconres\BILLSTATUS-116-sconres.zip
# Deleted ./data\BILLSTATUS\116\sjres\BILLSTATUS-116-sjres.zip
# Deleted ./data\BILLSTATUS\116\sres\BILLSTATUS-116-sres.zip
# Deleted ./data\BILLSTATUS\117\hconres\BILLSTATUS-117-hconres.zip
# Deleted ./data\BILLSTATUS\117\hjres\BILLSTATUS-117-hjres.zip
# Deleted ./data\BILLSTATUS\117\hr\BILLSTATUS-117-hr.zip
# Deleted ./data\BILLSTATUS\117\hres\BILLSTATUS-117-hres.zip
# Deleted ./data\BILLSTATUS\117\s\BILLSTATUS-117-s.zip
# Deleted ./data\BILLSTATUS\117\sconres\BILLSTATUS-117-sconres.zip
# Deleted ./data\BILLSTATUS\117\sjres\BILLSTATUS-117-sjres.zip
# Deleted ./data\BILLSTATUS\117\sres\BILLSTATUS-117-sres.zip
# Deleted ./data\BILLSTATUS\118\hconres\BILLSTATUS-118-hconres.zip
# Deleted ./data\BILLSTATUS\118\hjres\BILLSTATUS-118-hjres.zip
# Deleted ./data\BILLSTATUS\118\hr\BILLSTATUS-118-hr.zip
# Deleted ./data\BILLSTATUS\118\hres\BILLSTATUS-118-hres.zip
# Deleted ./data\BILLSTATUS\118\s\BILLSTATUS-118-s.zip
# Deleted ./data\BILLSTATUS\118\sconres\BILLSTATUS-118-sconres.zip
# Deleted ./data\BILLSTATUS\118\sjres\BILLSTATUS-118-sjres.zip
# Deleted ./data\BILLSTATUS\118\sres\BILLSTATUS-118-sres.zip
# Deleted ./data\billsummaries\113\hconres\BILLSUM-113-hconres.zip
# Deleted ./data\billsummaries\113\hjres\BILLSUM-113-hjres.zip
# Deleted ./data\billsummaries\113\hr\BILLSUM-113-hr.zip
# Deleted ./data\billsummaries\113\hres\BILLSUM-113-hres.zip
# Deleted ./data\billsummaries\113\s\BILLSUM-113-s.zip
# Deleted ./data\billsummaries\113\sconres\BILLSUM-113-sconres.zip
# Deleted ./data\billsummaries\113\sjres\BILLSUM-113-sjres.zip
# Deleted ./data\billsummaries\113\sres\BILLSUM-113-sres.zip
# Deleted ./data\billsummaries\114\hconres\BILLSUM-114-hconres.zip
# Deleted ./data\billsummaries\114\hjres\BILLSUM-114-hjres.zip
# Deleted ./data\billsummaries\114\hr\BILLSUM-114-hr.zip
# Deleted ./data\billsummaries\114\hres\BILLSUM-114-hres.zip
# Deleted ./data\billsummaries\114\s\BILLSUM-114-s.zip
# Deleted ./data\billsummaries\114\sconres\BILLSUM-114-sconres.zip
# Deleted ./data\billsummaries\114\sjres\BILLSUM-114-sjres.zip
# Deleted ./data\billsummaries\114\sres\BILLSUM-114-sres.zip
# Deleted ./data\billsummaries\115\hconres\BILLSUM-115-hconres.zip
# Deleted ./data\billsummaries\115\hjres\BILLSUM-115-hjres.zip
# Deleted ./data\billsummaries\115\hr\BILLSUM-115-hr.zip
# Deleted ./data\billsummaries\115\hres\BILLSUM-115-hres.zip
# Deleted ./data\billsummaries\115\s\BILLSUM-115-s.zip
# Deleted ./data\billsummaries\115\sconres\BILLSUM-115-sconres.zip
# Deleted ./data\billsummaries\115\sjres\BILLSUM-115-sjres.zip
# Deleted ./data\billsummaries\115\sres\BILLSUM-115-sres.zip
# Deleted ./data\billsummaries\116\hconres\BILLSUM-116-hconres.zip
# Deleted ./data\billsummaries\116\hjres\BILLSUM-116-hjres.zip
# Deleted ./data\billsummaries\116\hr\BILLSUM-116-hr.zip
# Deleted ./data\billsummaries\116\hres\BILLSUM-116-hres.zip
# Deleted ./data\billsummaries\116\s\BILLSUM-116-s.zip
# Deleted ./data\billsummaries\116\sconres\BILLSUM-116-sconres.zip
# Deleted ./data\billsummaries\116\sjres\BILLSUM-116-sjres.zip
# Deleted ./data\billsummaries\116\sres\BILLSUM-116-sres.zip
# Deleted ./data\billsummaries\117\hconres\BILLSUM-117-hconres.zip
# Deleted ./data\billsummaries\117\hjres\BILLSUM-117-hjres.zip
# Deleted ./data\billsummaries\117\hr\BILLSUM-117-hr.zip
# Deleted ./data\billsummaries\117\hres\BILLSUM-117-hres.zip
# Deleted ./data\billsummaries\117\s\BILLSUM-117-s.zip
# Deleted ./data\billsummaries\117\sconres\BILLSUM-117-sconres.zip
# Deleted ./data\billsummaries\117\sjres\BILLSUM-117-sjres.zip
# Deleted ./data\billsummaries\117\sres\BILLSUM-117-sres.zip
# Deleted ./data\billsummaries\118\hconres\BILLSUM-118-hconres.zip
# Deleted ./data\billsummaries\118\hjres\BILLSUM-118-hjres.zip
# Deleted ./data\billsummaries\118\hr\BILLSUM-118-hr.zip
# Deleted ./data\billsummaries\118\hres\BILLSUM-118-hres.zip
# Deleted ./data\billsummaries\118\s\BILLSUM-118-s.zip
# Deleted ./data\billsummaries\118\sconres\BILLSUM-118-sconres.zip
# Deleted ./data\billsummaries\118\sjres\BILLSUM-118-sjres.zip
# Deleted ./data\billsummaries\118\sres\BILLSUM-118-sres.zip
