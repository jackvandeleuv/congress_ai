# %%
import pandas as pd
import os
from search_engine import SearchEngine

engine = SearchEngine()

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)

# %%
optimal = pd.read_csv('./crs_matches_with_congresses_12-7-23.csv')

# Clean up the congress_match name
optimal['match'] = optimal['match'].apply(lambda x: x.replace('\n', ''))

# Attach report name
report_names = pd.read_csv('./SearchResults.csv')
optimal['ProductNumber'] = optimal.path.apply(lambda x: x.split('.')[0])
optimal = optimal.merge(report_names[['ProductNumber', 'Title']], on='ProductNumber', how='inner')

optimal.groupby('Title').size().sort_values(ascending=False).head(150).index.values.tolist()
# Out:
# ['Drug Pricing and Intellectual Property: The Legislative Landscape for the 117th Congress',
#  "Changes in the House of Representatives' Initial Consideration of Regular Appropriations Measures, 113th-116th Congresses",
#  'U.S. Sanctions: Legislation in the 117th Congress',
#  'Unemployment Insurance: Legislative Issues in the 117th Congress, First Session',
#  'Proposals for a COVID-19 Congressional Advisory Commission in the 117th Congress: A Comparative Analysis',
#  'Tax Provisions in the Build Back Better Act: Rules Committee Print 117-18',
#  'Immigration Legislation and Issues in the 117th Congress',
#  'Workforce Innovation and Opportunity Act of 2022 (H.R. 7309)',
#  'Senate Finance Committee Tax Provisions in the Build Back Better Act',
#  'Department of Homeland Security Appropriations: FY2022',
#  'Build Back Better Act (BBBA) Health Coverage Provisions: House-Passed and Senate-Released Language',
#  'Alternative Fuels and Vehicles: Legislative Proposals',
#  'Commander John Scott Hannon Veterans Mental Health Care Improvement Act of 2019 (P.L. 116-171) and Veterans COMPACT Act of 2020 (P.L. 116-214)',
#  'National Apprenticeship Act of 2021 (H.R. 447)',
#  'Labor, Health and Human Services, and Education: FY2021 Appropriations',
#  'Legislative Branch: FY2022 Appropriations ',
#  'Voter Registration Records and List Maintenance for Federal Elections',
#  'Labor, Health and Human Services, and Education: FY2022 Appropriations',
#  'FY2021 Defense Appropriations Act: Context and Selected Issues for Congress',
#  'Department of Veterans Affairs FY2022 Appropriations',
#  'Military Justice Disposition Delimitation Legislation in the 117th Congress',
#  'The American Innovation and Choice Online Act',
#  'Enhancing the Foreign Agents Registration Act of 1938',
#  'FY2022 National Defense Authorization Act: Context and Selected Issues for Congress',
#  'Title 36 Charters: The History and Evolution of Congressional Practices',
#  'Federal Firearms Law: Selected Developments in the Executive, Legislative, and Judicial Branches',
#  'Federal Research and Development (R&D) Funding: FY2022',
#  'Energy and Water Development: FY2022 Appropriations',
#  'Advanced Research Projects Agency for Health (ARPA-H): Congressional Action and Selected Policy Issues',
#  'FY2022 Defense Appropriations Act: Context and Selected Issues ',
#  'Examining Stock Trading Reforms For Congress',
#  'Cuba: U.S. Policy in the 117th Congress',
#  'Latin America and the Caribbean: U.S. Policy and Key Issues in the 117th Congress',
#  'FY2021 National Defense Authorization Act: Context and Selected Issues for Congress',
#  'Overview of the Universal Service Fund and Selected Federal Broadband Programs',
#  'Climate Change Adaptation: Department of Commerce',
#  'FY2021 National Defense Authorization Act: Selected Personnel and Health Care Issues',
#  'U.S. Climate Change Policy',
#  'Tax Provisions in the Inflation Reduction Act of 2022 (H.R. 5376)',
#  'Marine Harmful Algal Blooms (HABs): Background, Statutory Authorities, and Issues for Congress',
#  'Permissible and Prohibited Uses of Campaign Funds: Frequently Asked Questions and Policy Overview',
#  'Department of State, Foreign Operations, and Related Programs: FY2022 Budget and Appropriations',
#  'Housing Issues in the 117th Congress',
#  'Overview of Federal Hate Crime Laws',
#  'FCC Spectrum Auction Authority: Background and Proposals for Extension',
#  'The Violence Against Women Act (VAWA) Reauthorization: Issues for Congress',
#  'Expanding Broadband: Potential Role of Municipal Networks to Address the Digital Divide',
#  'Temporary Professional Foreign Workers: Background, Trends, and Policy Issues',
#  'Status of FY2022 Labor, Health and Human Services, and Education Appropriations: In Brief',
#  'Immunization Information Systems: Overview and Current Issues',
#  'Domestic Terrorism: Overview of Federal Criminal Law and Constitutional Issues',
#  "Stepping In: The FCC's Authority to Preempt State Laws Under the Communications Act",
#  'Computer Matching and Privacy Protection Act: Data Integration and Individual Rights',
#  'Food Insecurity Among College Students: Background and Policy Options ',
#  'Overview of COVID-19 LHHS Supplemental Appropriations: FY2020 and FY2021',
#  'Preparing for the Next Farm Bill',
#  'Student Athlete Name, Image, Likeness Legislation: Considerations for the 117th Congress',
#  'The Application of Internal Revenue Code Section 280E to Marijuana Businesses: Selected Legal Issues',
#  'Department of Homeland Security Appropriations: FY2021',
#  'DC Statehood: Constitutional Considerations for Proposed Legislation',
#  'Section 230: An Overview',
#  'Unemployment Insurance: Program Integrity and Fraud Concerns Related to the COVID-19 Pandemic Response',
#  'Firearm Background Checks Under H.R. 8 and H.R. 1446',
#  'Social Media: Misinformation and Content Moderation Issues for Congress',
#  'Service-Disabled Veteran-Owned Small Business Procurement Program',
#  'The American Rescue Plan Act of 2021 (ARPA; P.L. 117-2): Title IX, Subtitle G-Tax Provisions Related to Promoting Economic Security ',
#  'Congress and the Middle East, 2011-2020: Selected Case Studies',
#  'Financial Services and General Government (FSGG) FY2022 Appropriations: Overview',
#  'Net Neutrality Law: An Overview',
#  'Naming VA Facilities',
#  'The Financial Crimes Enforcement Network (FinCEN): Anti-Money Laundering Act of 2020 Implementation and Beyond',
#  'The 90/10 Rule Under HEA Title IV: Background and Issues',
#  'Transportation, Housing and Urban Development, and Related Agencies (THUD) Appropriations for FY2022',
#  'Congressional Redistricting: Key Legal and Policy Issues',
#  'Agriculture and Related Agencies: FY2022 Appropriations',
#  'Judiciary Appropriations, FY2022',
#  'The National Science Foundation: An Overview',
#  'Dam Removal and the Federal Role',
#  'U.S. Employment-Based Immigration Policy',
#  'Farm Bill Primer: Beginning and Underserved Producers ',
#  'Patents and Innovation Policy',
#  'Voting Rights Act and H.R. 4 (117th Congress): An Overview',
#  'Federal Role in Preventing Evictions',
#  'Social Security: Trust Fund Status in the Early 1980s and Today and the 1980s Greenspan Commission',
#  'U.S. Foreign Assistance to Latin America and the Caribbean: FY2022 Appropriations',
#  "The Modernizing Veterans' Health Care Eligibility Act (H.R. 1216), and other Pending Legislation",
#  'Congressional Oversight of the State Department: Review of Selected Organizational Reform Efforts',
#  'GILTI: Proposed Changes in the Taxation of Global Intangible Low-Taxed Income',
#  'Capital Gains Taxes: An Overview of the Issues',
#  'USDA Rural Broadband, Electric, and Water Programs: FY2022 Appropriations',
#  'Regular Appropriations Acts: Selected Statutory Interpretation Issues',
#  'Advanced Research Projects Agency for Health (ARPA-H): Potential Questions for Consideration',
#  'American Rescue Plan Act of 2021 (P.L. 117-2): Private Health Insurance, Medicaid, CHIP, and Medicare Provisions',
#  'House-Passed Assault Weapons Ban of 2022 (H.R. 1808)',
#  'U.S. International Development Finance Corporation: Overview and Issues',
#  'Agricultural Conservation: FY2022 Appropriations',
#  'Proposed Tobacco Excise Tax Changes in H.R. 5376, the Reconciliation Bill',
#  'U.S. Fish and Wildlife Service: FY2022 Appropriations',
#  'Mens Rea: An Overview of State-of-Mind Requirements for Federal Criminal Offenses',
#  'Short- and Long-Term Solutions to Extreme Drought in the Western United States',
#  'Firearms Eligibility: Stalking- and Domestic Violence-Related Provisions in H.R. 1620',
#  'FY2021 District of Columbia Budget and Appropriations',
#  'Trade-Related Agencies: FY2022 Appropriations, Commerce, Science, Justice and Related Agencies (CJS)',
#  'Election Administration: An Introduction to Risk-Limiting Audits',
#  'Racial and Ethnic Equity in U.S. Agriculture: Selected Current Issues',
#  "Estimated 'Direct Payments' by State Under the House and Senate Versions of the American Rescue Plan Act of 2021 (H.R. 1319)",
#  'Recreational Access Acquisitions: Overview and Recent Funding History',
#  'U.S. Restrictions on Huawei Technologies: National Security, Foreign Policy, and Economic Interests',
#  "USDA's ReConnect Program: Expanding Rural Broadband",
#  'H.R. 3233, the National Commission to Investigate the January 6 Attack on the United States Capitol Complex Act',
#  'Navigating the Appropriations Status Table',
#  'Comparing DHS Component Funding Proposals, FY2022: In Brief',
#  'Social Security: The Effects of Wage and Price Indexing on Benefits',
#  'Farm Bill Primer: Horticulture Title and Related Provisions',
#  'Federal Pay: General Schedule (GS) Pay Adjustment Process, Amounts Provided Since 2010, and Issues for Congress',
#  'District of Columbia Voting Representation Proposals in the 117th Congress',
#  'The Beijing 2022 Olympic and Paralympic Winter Games: Issues for Congress',
#  'Children in Foster Care and Social Security Administration Benefits: Frequently Asked Questions',
#  'Artificial Intelligence: Background, Selected Issues, and Policy Considerations',
#  'Interior, Environment, and Related Agencies: Overview of FY2022 Appropriations',
#  'Congressional Redistricting Criteria and Considerations',
#  'Clean Energy Standards: Selected Issues for the 117th Congress',
#  'Blockchain: Novel Provenance Applications',
#  'Superfund Tax Legislation in the 117th Congress',
#  'Critical Infrastructure Risk Management: Securing the Oil and Gas Supply Chain',
#  'Worker Rights Provisions and U.S. Trade Policy',
#  "Puerto Rico's Public Debts: Accumulation and Restructuring",
#  'The Federal Communications Commission: Selected Issues Under Consideration',
#  'FY2022 District of Columbia Budget and Appropriations',
#  'Amending Eligibility Rules for Free and Reduced-Price School Meals: Background and Policy Options',
#  'The Bioeconomy: A Primer',
#  'FY2023 NDAA: Status of Legislative Activity',
#  'Corporate Income Taxation in a Global Economy',
#  'Trends and Proposals for Corporate Tax Revenue',
#  'FY2022 Reconciliation: Title IV, House Financial Services Committee Provisions',
#  'The Metaverse: Concepts and Issues for Congress',
#  'Suspension of the Rules: House Practice in the 116th Congress (2019-2020)',
#  'U.S. Military Withdrawal and Taliban Takeover in Afghanistan: Frequently Asked Questions',
#  'Pipeline Cybersecurity: Federal Programs',
#  'FY2023 NDAA: Summary of Funding Authorizations',
#  'Scope of CDC Authority Under Section 361 of the Public Health Service Act (PHSA)',
#  'The Law of Asylum Procedure at the Border: Statutes and Agency Implementation',
#  'FY2021 Appropriations for Agricultural Conservation',
#  'Federal Research and Development (R&D) Funding: FY2023',
#  'Taliban Government in Afghanistan: Background and Issues for Congress ',
#  'Minimum Taxes on Business Income: Background and Policy Options',
#  'What Is the Blue Economy?',
#  'Bipartisan Safer Communities Act (P.L. 117-159): Section-by-Section Summary',
#  'Modernizing Access to Military Service Records: Frequently Asked Questions',
#  'Build Back Better Act Methane Emissions Charge: In Brief']

# %%
# Map CRS titles to manually create queries
queries = {
    'Drug Pricing and Intellectual Property: The Legislative Landscape for the 117th Congress': [
        'drug pricing and intellectual property',
        'drug pricing',
        'intellectual property'
    ],
    'U.S. Sanctions: Legislation in the 117th Congress': [
        'us sanctions',
        'u.s. sanctions',
        'united states sanctions'
    ],
    'Unemployment Insurance: Legislative Issues in the 117th Congress, First Session': [
        'unemployment insurance'
    ],
    'Tax Provisions in the Build Back Better Act: Rules Committee Print 117-18': [
        'tax provisions build back better act',
        'build back better act',
        'build back better',
        'tax provisions in the build back better act, rules committee',
        'build back better rules committee'
    ],
    'Immigration Legislation and Issues in the 117th Congress': [
        'immigration'
    ],
    'Workforce Innovation and Opportunity Act of 2022 (H.R. 7309)': [
        'workforce innovation and opportunity act of 2022',
        'workforce innovation and opportunity act',
        'workforce innovation and opportunity',
        'workplace innovation',
        'H.R. 7309'
    ],
    'Department of Homeland Security Appropriations: FY2022': [
        'department of homeland security appropriations',
        'homeland security',
        'homeland security appropriations',
        'homeland security FY2022',
        'homeland security 2022'
    ],
    'Alternative Fuels and Vehicles: Legislative Proposals': [
        'alternative fuels and vehicles',
        'alternative fuels',
    ],
    'Voter Registration Records and List Maintenance for Federal Elections': [
        'voter registration',
        'voter registration records for federal election',
        'federal voter registration',
        'voter registration records and list maintenance'
    ],
    'Federal Firearms Law: Selected Developments in the Executive, Legislative, and Judicial Branches': [
        'firearms law',
        'federal firearms law'
    ],
    'Federal Research and Development (R&D) Funding: FY2022': [
        'federal r&d',
        'federal research and development',
        'r&d funding 2022'
    ],
    'Energy and Water Development: FY2022 Appropriations': [
        'energy and water development',
        'energy and water appropriations'
    ],
    'Advanced Research Projects Agency for Health (ARPA-H): Congressional Action and Selected Policy Issues': [
        'arpa-h',
        'advanced research projects agency for health',
        'arpa health'
    ],
    'Climate Change Adaptation: Department of Commerce': [
        'climate change adaptation',
        'climate change',
        'climate change adaptation department of commerce',
        'climate adaptation commerce department'
    ],
    'Marine Harmful Algal Blooms (HABs): Background, Statutory Authorities, and Issues for Congress': [
        'marine harmful algal blooms',
        'harmful algae',
        'marine harmful algal blooms statutory authorities'
    ],
    'Expanding Broadband: Potential Role of Municipal Networks to Address the Digital Divide': [
        'municipal networks digital divide',
        'municipal networks',
        'expanding broadband digital divide',
        'municipal broadband'
    ],
    'Food Insecurity Among College Students: Background and Policy Options ': [
        'food insecurity',
        'food insecurity college students'
    ],
    'Dam Removal and the Federal Role': [
        'dam removal'
    ],
    'Capital Gains Taxes: An Overview of the Issues': [
        'capital gains taxes'
    ],
    'Pipeline Cybersecurity: Federal Programs': [
        'pipeline cybersecurity'
    ],
    "Puerto Rico's Public Debts: Accumulation and Restructuring": [
        'puerto rico debt',
        'puerto rico public debt',
        'puerto rico public debt restructuring'
    ]
    
}

# %%
data = [(key, value) for key, values in queries.items() for value in values]
manual = pd.DataFrame(data, columns=['Title', 'Query'])

# %%
manual.head(5)
# Out:
#                                                Title  \
# 0  Drug Pricing and Intellectual Property: The Le...
# 1  Drug Pricing and Intellectual Property: The Le...
# 2  Drug Pricing and Intellectual Property: The Le...
# 3  U.S. Sanctions: Legislation in the 117th Congress
# 4  U.S. Sanctions: Legislation in the 117th Congress
#
#                                     Query
# 0  drug pricing and intellectual property
# 1                            drug pricing
# 2                   intellectual property
# 3                            us sanctions
# 4                          u.s. sanctions

# %%
# Reformat to match the results dataframes
optimal['primary_key'] = 'hr_' + optimal['match'].apply(lambda x: x.split(' ')[-1]) + '_' + optimal.congress_match

# Merge with the manually-generated queries
optimal = optimal.merge(manual, on='Title', how='left')
optimal = optimal[optimal['Query'].notna()]

# %% [markdown]
# Now go to congress.gov and manually enter these queries. Filter to return H.R. only, and only the previous 10 congresses (otherwise there will be too many results to bulk download, as congress.gov limits it to 5000).
#
# Search all fields, including bill text.
#
# These have too many results on congress.gov to bulk download:
# * federal r&d   # FAILED
# * federal research and development  # FAILED
# * homeland security   # FAILED
# * immigration   # FAILED

# %%
print(optimal.Query.nunique())
for q in optimal.Query.unique().tolist():
    print(q)
# Out:
# 58
# drug pricing and intellectual property
# drug pricing
# intellectual property
# climate change adaptation
# climate change
# climate change adaptation department of commerce
# climate adaptation commerce department
# puerto rico debt
# puerto rico public debt
# puerto rico public debt restructuring
# unemployment insurance
# food insecurity
# food insecurity college students
# energy and water development
# energy and water appropriations
# alternative fuels and vehicles
# alternative fuels
# federal r&d
# federal research and development
# r&d funding 2022
# pipeline cybersecurity
# marine harmful algal blooms
# harmful algae
# marine harmful algal blooms statutory authorities
# voter registration
# voter registration records for federal election
# federal voter registration
# voter registration records and list maintenance
# dam removal
# firearms law
# federal firearms law
# tax provisions build back better act
# build back better act
# build back better
# tax provisions in the build back better act, rules committee
# build back better rules committee
# department of homeland security appropriations
# homeland security
# homeland security appropriations
# homeland security FY2022
# homeland security 2022
# immigration
# arpa-h
# advanced research projects agency for health
# arpa health
# workforce innovation and opportunity act of 2022
# workforce innovation and opportunity act
# workforce innovation and opportunity
# workplace innovation
# H.R. 7309
# capital gains taxes
# municipal networks digital divide
# municipal networks
# expanding broadband digital divide
# municipal broadband
# us sanctions
# u.s. sanctions
# united states sanctions

# %%
import numpy as np

def calculate_map(retrieved_docs_df, relevant_docs):
    rel_ret_at_k = 0
    precision = []

    for i, row in retrieved_docs_df.iterrows():
        rank = i + 1
        if row['primary_key'] in relevant_docs:
            rel_ret_at_k += 1
            p_at_k = rel_ret_at_k / rank
            precision.append(p_at_k)

    for _ in range(len(relevant_docs - set(retrieved_docs_df.primary_key.values))):
        precision.append(0)

    return np.mean(precision)

# %%
bert_mrrs = []
congress_mrrs = []

bert_p50s = []
congress_p50s = []
bert_p500s = []
congress_p500s = []

bert_r50s = []
congress_r50s = []
bert_r500s = []
congress_r500s = []

bert_map = []
congress_map = []

for i, path in enumerate(os.listdir('./congress_gov_searches/')):
    query = path.split('.csv')[0]

    # PARAMETERIZATION BUG THAT NEEDS TO BE ADDRESSED
    if query in ['arpa-h', 'r&d funding 2022']:
        continue

    print(f'\nProcessing query {i}:', query)

    congress_gov = pd.read_csv(
        f'./congress_gov_searches/{query}.csv', 
        skiprows=2
    )
    # Get top 1000
    congress_gov = congress_gov[:1000]
    congress_gov['primary_key'] = 'hr_' + congress_gov['Legislation Number'] \
        .apply(lambda x: x.lower().split(' ')[1]) + '_' + congress_gov['Congress'].apply(lambda x: x.split(' ')[0])

    params = {
        'query': query,
        'number_to_return': 1000,
        'exact_match_strings': [],  
        'date_range': {
            'start_year': 1970,
            'start_month': 1,
            'start_day': 1,
            'end_year': 2050,
            'end_month': 12,
            'end_day': 31
        },
        'get_sponsors': False,
        'chamber': 'any',
        'require_bipartisan': False
    }

    bert_result = engine.retrieve_summary(params)
    bert = pd.DataFrame(bert_result)
    bert['primary_key'] = 'hr_' + bert.bill_number.astype(str) + '_' + bert.congress.astype(str) + 'th'

    optimal_this_query = optimal[optimal['Query'] == query]
    relevant_docs = optimal_this_query.primary_key.values

    bert_filter = bert[bert.primary_key.isin(relevant_docs)]
    congress_filter = congress_gov[congress_gov.primary_key.isin(relevant_docs)]

    # Calculate BERT MRR
    if len(bert_filter) > 0:
        bert_mrr = 1 / (1 + bert_filter.index.values[0])
        bert_mrrs.append(bert_mrr)
    else:
        bert_mrrs.append(0)

    # Calculate Congress MRR
    if len(congress_filter) > 0:
        congress_mrr = 1 / (1 + congress_filter.index.values[0])
        congress_mrrs.append(congress_mrr)
    else:
        congress_mrrs.append(0)


    # Calculate BERT Precision@50
    if len(bert_filter) > 0:
        bert50 = bert[:50]
        p50 = bert50[bert50.primary_key.isin(relevant_docs)].primary_key.nunique() / 50
        bert_p50s.append(p50)
    else:
        bert_p50s.append(0)

    # Calculate Congress Precision@50
    if len(congress_filter) > 0:
        congress50 = congress_gov[:50]
        p50 = congress50[congress50.primary_key.isin(relevant_docs)].primary_key.nunique() / 50
        congress_p50s.append(p50)
    else:
        congress_p50s.append(0)

    # Calculate BERT Precision@500
    if len(bert_filter) > 0:
        bert500 = bert[:500]
        p500 = bert500[bert500.primary_key.isin(relevant_docs)].primary_key.nunique() / 500
        bert_p500s.append(p500)
    else:
        bert_p500s.append(0)

    # Calculate Congress Precision@500
    if len(congress_filter) > 0:
        congress500 = congress_gov[:500]
        p500 = congress500[congress500.primary_key.isin(relevant_docs)].primary_key.nunique() / 500
        congress_p500s.append(p500)
    else:
        congress_p500s.append(0)

    # Calculate BERT r@50
    if len(bert_filter) > 0:
        bert50 = bert[:50]
        r50 = bert50[bert50.primary_key.isin(relevant_docs)].primary_key.nunique() / optimal_this_query.primary_key.nunique()
        bert_r50s.append(r50)
    else:
        bert_r50s.append(0)

    # Calculate Congress r@50
    if len(congress_filter) > 0:
        congress50 = congress_gov[:50]
        r50 = congress50[congress50.primary_key.isin(relevant_docs)].primary_key.nunique() / optimal_this_query.primary_key.nunique()
        congress_r50s.append(r50)
    else:
        congress_r50s.append(0)

    # Calculate BERT r@500
    if len(bert_filter) > 0:
        bert500 = bert[:500]
        r500 = bert500[bert500.primary_key.isin(relevant_docs)].primary_key.nunique() / optimal_this_query.primary_key.nunique()
        bert_r500s.append(r500)
    else:
        bert_r500s.append(0)

    # Calculate Congress r@500
    if len(congress_filter) > 0:
        congress500 = congress_gov[:500]
        r500 = congress500[congress500.primary_key.isin(relevant_docs)].primary_key.nunique() / optimal_this_query.primary_key.nunique()
        congress_r500s.append(r500)
    else:
        congress_r500s.append(0)

    if len(bert_filter) > 0:    
        bert_map.append(calculate_map(bert, set(relevant_docs)))
    else:
        bert_map.append(0)

    if len(congress_filter) > 0:
        congress_map.append(calculate_map(congress_gov, set(relevant_docs)))
    else:
        congress_map.append(0)
# Out:
# Processing query 0: advanced research projects agency for health
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['project OR research OR advanc OR agenc OR health', '500', '500']
# Get initial docs: 1.5150096416473389
# Get precomputed embeddings: 0.45245885848999023
# Clean query: 0.0
# Embed query: 0.0458829402923584
# Score docs: 0.01630687713623047
# BERT rerank: 0.5417466163635254
# Get remaining data: 0.22310209274291992
# Get sponsors: 0.0
#
# Processing query 1: alternative fuels and vehicles
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['fuel OR altern OR vehicl', '500', '500']
# Get initial docs: 1.0515022277832031
# Get precomputed embeddings: 0.3597407341003418
# Clean query: 0.0
# Embed query: 0.01770639419555664
# Score docs: 0.00705409049987793
# BERT rerank: 0.40244078636169434
# Get remaining data: 0.2500009536743164
# Get sponsors: 0.0
#
# Processing query 2: alternative fuels
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['fuel OR altern', '500', '500']
# Get initial docs: 0.6171660423278809
# Get precomputed embeddings: 0.2501029968261719
# Clean query: 0.0010225772857666016
# Embed query: 0.008467435836791992
# Score docs: 0.0034792423248291016
# BERT rerank: 0.3000502586364746
# Get remaining data: 0.09819865226745605
# Get sponsors: 0.0
#
# Processing query 3: arpa health
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['arpa OR health', '500', '500']
# Get initial docs: 1.34869384765625
# Get precomputed embeddings: 0.3282632827758789
# Clean query: 0.0
# Embed query: 0.009118318557739258
# Score docs: 0.005055427551269531
# BERT rerank: 0.3658487796783447
# Get remaining data: 0.21155095100402832
# Get sponsors: 0.0
#
# Processing query 5: build back better act
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['act OR build OR better OR back', '500', '500']
# Get initial docs: 0.9857430458068848
# Get precomputed embeddings: 0.6099817752838135
# Clean query: 0.0
# Embed query: 0.01036691665649414
# Score docs: 0.014679908752441406
# BERT rerank: 0.6598916053771973
# Get remaining data: 0.08196163177490234
# Get sponsors: 0.0
#
# Processing query 6: build back better rules committee
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['committe OR better OR rule OR build OR back', '500', '500']
# Get initial docs: 0.42281484603881836
# Get precomputed embeddings: 0.21361231803894043
# Clean query: 0.001001119613647461
# Embed query: 0.01548147201538086
# Score docs: 0.011308908462524414
# BERT rerank: 0.270078182220459
# Get remaining data: 0.046448469161987305
# Get sponsors: 0.0
#
# Processing query 7: build back better
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['build OR better OR back', '500', '500']
# Get initial docs: 0.13024401664733887
# Get precomputed embeddings: 0.02207803726196289
# Clean query: 0.0
# Embed query: 0.01795482635498047
# Score docs: 0.015275955200195312
# BERT rerank: 0.08523702621459961
# Get remaining data: 0.017095327377319336
# Get sponsors: 0.0
#
# Processing query 8: capital gains taxes
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['capit OR tax OR gain', '500', '500']
# Get initial docs: 0.6282963752746582
# Get precomputed embeddings: 0.3502652645111084
# Clean query: 0.0
# Embed query: 0.008534908294677734
# Score docs: 0.00903177261352539
# BERT rerank: 0.38858604431152344
# Get remaining data: 0.17917394638061523
# Get sponsors: 0.0
#
# Processing query 9: climate adaptation commerce department
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['climat OR depart OR adapt OR commerc', '500', '500']
# Get initial docs: 0.7656593322753906
# Get precomputed embeddings: 0.39341068267822266
# Clean query: 0.000507354736328125
# Embed query: 0.010996103286743164
# Score docs: 0.012856483459472656
# BERT rerank: 0.445720911026001
# Get remaining data: 0.2046797275543213
# Get sponsors: 0.0
#
# Processing query 10: climate change adaptation department of commerce
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['adapt OR climat OR chang OR commerc OR depart', '500', '500']
# Get initial docs: 0.8766767978668213
# Get precomputed embeddings: 0.052265167236328125
# Clean query: 0.0
# Embed query: 0.01738262176513672
# Score docs: 0.005301237106323242
# BERT rerank: 0.09497237205505371
# Get remaining data: 0.05929255485534668
# Get sponsors: 0.0
#
# Processing query 11: climate change adaptation
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['climat OR chang OR adapt', '500', '500']
# Get initial docs: 0.30992817878723145
# Get precomputed embeddings: 0.05981326103210449
# Clean query: 0.0
# Embed query: 0.01570916175842285
# Score docs: 0.0025169849395751953
# BERT rerank: 0.09766125679016113
# Get remaining data: 0.032109737396240234
# Get sponsors: 0.0
#
# Processing query 12: climate change
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['climat OR chang', '500', '500']
# Get initial docs: 0.41968822479248047
# Get precomputed embeddings: 0.17103791236877441
# Clean query: 0.0
# Embed query: 0.008507728576660156
# Score docs: 0.006675243377685547
# BERT rerank: 0.20218110084533691
# Get remaining data: 0.050090789794921875
# Get sponsors: 0.0
#
# Processing query 13: dam removal
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['dam OR remov', '500', '500']
# Get initial docs: 0.4781301021575928
# Get precomputed embeddings: 0.35175395011901855
# Clean query: 0.0
# Embed query: 0.0202634334564209
# Score docs: 0.008051395416259766
# BERT rerank: 0.3949756622314453
# Get remaining data: 0.13489341735839844
# Get sponsors: 0.0
#
# Processing query 14: department of homeland security appropriations
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['depart OR appropri OR secur OR homeland', '500', '500']
# Get initial docs: 0.7860486507415771
# Get precomputed embeddings: 0.3505730628967285
# Clean query: 0.0
# Embed query: 0.01857733726501465
# Score docs: 0.0048978328704833984
# BERT rerank: 0.3909919261932373
# Get remaining data: 0.18172311782836914
# Get sponsors: 0.0
#
# Processing query 15: drug pricing and intellectual property
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['drug OR properti OR price OR intellectu', '500', '500']
# Get initial docs: 0.7829246520996094
# Get precomputed embeddings: 0.3467280864715576
# Clean query: 0.0
# Embed query: 0.0125885009765625
# Score docs: 0.011350393295288086
# BERT rerank: 0.38738369941711426
# Get remaining data: 0.16958165168762207
# Get sponsors: 0.0
#
# Processing query 16: drug pricing
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['drug OR price', '500', '500']
# Get initial docs: 0.4261167049407959
# Get precomputed embeddings: 0.3197453022003174
# Clean query: 0.0
# Embed query: 0.012374639511108398
# Score docs: 0.0077631473541259766
# BERT rerank: 0.36182308197021484
# Get remaining data: 0.0969395637512207
# Get sponsors: 0.0
#
# Processing query 17: energy and water appropriations
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['water OR appropri OR energi', '500', '500']
# Get initial docs: 0.8013882637023926
# Get precomputed embeddings: 0.31999874114990234
# Clean query: 0.0
# Embed query: 0.019812583923339844
# Score docs: 0.005126237869262695
# BERT rerank: 0.3620471954345703
# Get remaining data: 0.15782690048217773
# Get sponsors: 0.0
#
# Processing query 18: energy and water development
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['water OR develop OR energi', '500', '500']
# Get initial docs: 0.5681931972503662
# Get precomputed embeddings: 0.15927362442016602
# Clean query: 0.0010166168212890625
# Embed query: 0.00938725471496582
# Score docs: 0.0025157928466796875
# BERT rerank: 0.19354748725891113
# Get remaining data: 0.0867300033569336
# Get sponsors: 0.0
#
# Processing query 19: expanding broadband digital divide
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['divid OR digit OR expand OR broadband', '500', '500']
# Get initial docs: 0.672050952911377
# Get precomputed embeddings: 0.33771634101867676
# Clean query: 0.0
# Embed query: 0.010300159454345703
# Score docs: 0.009038209915161133
# BERT rerank: 0.3767979145050049
# Get remaining data: 0.16094613075256348
# Get sponsors: 0.0
#
# Processing query 20: federal firearms law
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['law OR feder OR firearm', '500', '500']
# Get initial docs: 0.8242244720458984
# Get precomputed embeddings: 0.40380334854125977
# Clean query: 0.0
# Embed query: 0.023340940475463867
# Score docs: 0.008704185485839844
# BERT rerank: 0.45887112617492676
# Get remaining data: 0.15607929229736328
# Get sponsors: 0.0
#
# Processing query 21: federal voter registration
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['voter OR feder OR registr', '500', '500']
# Get initial docs: 0.9551317691802979
# Get precomputed embeddings: 0.353924036026001
# Clean query: 0.0
# Embed query: 0.01145172119140625
# Score docs: 0.013393163681030273
# BERT rerank: 0.39687085151672363
# Get remaining data: 0.1477804183959961
# Get sponsors: 0.0
#
# Processing query 22: firearms law
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['law OR firearm', '500', '500']
# Get initial docs: 0.17873048782348633
# Get precomputed embeddings: 0.015556812286376953
# Clean query: 0.0
# Embed query: 0.014848470687866211
# Score docs: 0.006427288055419922
# BERT rerank: 0.05583500862121582
# Get remaining data: 0.01284480094909668
# Get sponsors: 0.0
#
# Processing query 23: food insecurity college students
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['insecur OR student OR colleg OR food', '500', '500']
# Get initial docs: 0.8699052333831787
# Get precomputed embeddings: 0.3599865436553955
# Clean query: 0.0
# Embed query: 0.009158611297607422
# Score docs: 0.004041194915771484
# BERT rerank: 0.3944871425628662
# Get remaining data: 0.15781307220458984
# Get sponsors: 0.0
#
# Processing query 24: food insecurity
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['insecur OR food', '500', '500']
# Get initial docs: 0.46967482566833496
# Get precomputed embeddings: 0.1698620319366455
# Clean query: 0.0
# Embed query: 0.012105941772460938
# Score docs: 0.009233474731445312
# BERT rerank: 0.21118736267089844
# Get remaining data: 0.07875776290893555
# Get sponsors: 0.0
#
# Processing query 25: H.R. 7309
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['7309 OR h OR r', '500', '500']
# Get initial docs: 0.5260531902313232
# Get precomputed embeddings: 0.03193068504333496
# Clean query: 0.008034706115722656
# Embed query: 0.012134075164794922
# Score docs: 0.0
# BERT rerank: 0.05209946632385254
# Get remaining data: 0.016973257064819336
# Get sponsors: 0.0
#
# Processing query 26: harmful algae
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['alga OR harm', '500', '500']
# Get initial docs: 0.45183229446411133
# Get precomputed embeddings: 0.3844938278198242
# Clean query: 0.0
# Embed query: 0.0010080337524414062
# Score docs: 0.012357950210571289
# BERT rerank: 0.43752241134643555
# Get remaining data: 0.10992693901062012
# Get sponsors: 0.0
#
# Processing query 27: homeland security 2022
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['2022 OR secur OR homeland', '500', '500']
# Get initial docs: 0.8303897380828857
# Get precomputed embeddings: 0.360668420791626
# Clean query: 0.0
# Embed query: 0.009188413619995117
# Score docs: 0.008536577224731445
# BERT rerank: 0.39235973358154297
# Get remaining data: 0.11560249328613281
# Get sponsors: 0.0
#
# Processing query 28: homeland security appropriations
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['appropri OR secur OR homeland', '500', '500']
# Get initial docs: 0.581881046295166
# Get precomputed embeddings: 0.413546085357666
# Clean query: 0.001005411148071289
# Embed query: 0.011301040649414062
# Score docs: 0.00901341438293457
# BERT rerank: 0.4574778079986572
# Get remaining data: 0.14443230628967285
# Get sponsors: 0.0
#
# Processing query 29: homeland security FY2022
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['fy2022 OR secur OR homeland', '500', '500']
# Get initial docs: 0.38858842849731445
# Get precomputed embeddings: 0.3890798091888428
# Clean query: 0.0
# Embed query: 0.008141279220581055
# Score docs: 0.010048389434814453
# BERT rerank: 0.42113757133483887
# Get remaining data: 0.13793158531188965
# Get sponsors: 0.0
#
# Processing query 30: intellectual property
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['properti OR intellectu', '500', '500']
# Get initial docs: 0.5392093658447266
# Get precomputed embeddings: 0.3109769821166992
# Clean query: 0.0
# Embed query: 0.012570381164550781
# Score docs: 0.007440090179443359
# BERT rerank: 0.36018800735473633
# Get remaining data: 0.14311742782592773
# Get sponsors: 0.0
#
# Processing query 31: marine harmful algal blooms statutory authorities
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['bloom OR algal OR statutori OR marin OR harm OR author', '500', '500']
# Get initial docs: 0.825814962387085
# Get precomputed embeddings: 0.25039148330688477
# Clean query: 0.0
# Embed query: 0.010291337966918945
# Score docs: 0.0
# BERT rerank: 0.28374600410461426
# Get remaining data: 0.12466025352478027
# Get sponsors: 0.0
#
# Processing query 32: marine harmful algal blooms
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['algal OR bloom OR harm OR marin', '500', '500']
# Get initial docs: 0.37511110305786133
# Get precomputed embeddings: 0.03817868232727051
# Clean query: 0.0
# Embed query: 0.01978325843811035
# Score docs: 0.010213375091552734
# BERT rerank: 0.08703994750976562
# Get remaining data: 0.0633080005645752
# Get sponsors: 0.0
#
# Processing query 33: municipal broadband
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['broadband OR municip', '500', '500']
# Get initial docs: 0.5426731109619141
# Get precomputed embeddings: 0.32076120376586914
# Clean query: 0.0
# Embed query: 0.02007317543029785
# Score docs: 0.009176492691040039
# BERT rerank: 0.36992454528808594
# Get remaining data: 0.16782402992248535
# Get sponsors: 0.0
#
# Processing query 34: municipal networks digital divide
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['divid OR digit OR network OR municip', '500', '500']
# Get initial docs: 0.5218923091888428
# Get precomputed embeddings: 0.2995624542236328
# Clean query: 0.0
# Embed query: 0.013222694396972656
# Score docs: 0.006377696990966797
# BERT rerank: 0.3470790386199951
# Get remaining data: 0.10109877586364746
# Get sponsors: 0.0
#
# Processing query 35: municipal networks
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['network OR municip', '500', '500']
# Get initial docs: 0.4784989356994629
# Get precomputed embeddings: 0.25345611572265625
# Clean query: 0.0
# Embed query: 0.01347970962524414
# Score docs: 0.0064008235931396484
# BERT rerank: 0.3031139373779297
# Get remaining data: 0.23845291137695312
# Get sponsors: 0.0
#
# Processing query 36: pipeline cybersecurity
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['cybersecur OR pipelin', '500', '500']
# Get initial docs: 0.47164344787597656
# Get precomputed embeddings: 0.32831859588623047
# Clean query: 0.0
# Embed query: 0.017708778381347656
# Score docs: 0.009015798568725586
# BERT rerank: 0.36821508407592773
# Get remaining data: 0.14001250267028809
# Get sponsors: 0.0
#
# Processing query 37: puerto rico debt
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['debt OR puerto OR rico', '500', '500']
# Get initial docs: 0.5153207778930664
# Get precomputed embeddings: 0.33063483238220215
# Clean query: 0.0
# Embed query: 0.008163690567016602
# Score docs: 0.010102987289428711
# BERT rerank: 0.36841893196105957
# Get remaining data: 0.14063191413879395
# Get sponsors: 0.0
#
# Processing query 38: puerto rico public debt restructuring
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['public OR debt OR restructur OR puerto OR rico', '500', '500']
# Get initial docs: 0.47370171546936035
# Get precomputed embeddings: 0.0563657283782959
# Clean query: 0.0
# Embed query: 0.014615297317504883
# Score docs: 0.0071163177490234375
# BERT rerank: 0.1049966812133789
# Get remaining data: 0.0246126651763916
# Get sponsors: 0.0
#
# Processing query 39: puerto rico public debt
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['public OR debt OR puerto OR rico', '500', '500']
# Get initial docs: 0.3222320079803467
# Get precomputed embeddings: 0.02407550811767578
# Clean query: 0.0010221004486083984
# Embed query: 0.01189732551574707
# Score docs: 0.00800943374633789
# BERT rerank: 0.06705307960510254
# Get remaining data: 0.019556760787963867
# Get sponsors: 0.0
#
# Processing query 41: tax provisions build back better act
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['provis OR act OR tax OR better OR build OR back', '500', '500']
# Get initial docs: 0.7825896739959717
# Get precomputed embeddings: 0.3552534580230713
# Clean query: 0.0
# Embed query: 0.01278376579284668
# Score docs: 0.010023117065429688
# BERT rerank: 0.3977196216583252
# Get remaining data: 0.15348219871520996
# Get sponsors: 0.0
#
# Processing query 42: tax provisions in the build back better act, rules committee
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['provis OR committe OR act OR tax OR better OR rule OR build OR back', '500', '500']
# Get initial docs: 1.0842621326446533
# Get precomputed embeddings: 0.19609808921813965
# Clean query: 0.008183956146240234
# Embed query: 0.011599540710449219
# Score docs: 0.011998414993286133
# BERT rerank: 0.24867987632751465
# Get remaining data: 0.06617975234985352
# Get sponsors: 0.0
#
# Processing query 43: u.s. sanctions
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['sanction OR u', '500', '500']
# Get initial docs: 0.8077833652496338
# Get precomputed embeddings: 0.35877013206481934
# Clean query: 0.0
# Embed query: 0.011918306350708008
# Score docs: 0.003025531768798828
# BERT rerank: 0.3949573040008545
# Get remaining data: 0.1522960662841797
# Get sponsors: 0.0
#
# Processing query 44: unemployment insurance
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['unemploy OR insur', '500', '500']
# Get initial docs: 0.43834519386291504
# Get precomputed embeddings: 0.3197510242462158
# Clean query: 0.0
# Embed query: 0.012407541275024414
# Score docs: 0.00882411003112793
# BERT rerank: 0.3589653968811035
# Get remaining data: 0.19265031814575195
# Get sponsors: 0.0
#
# Processing query 45: united states sanctions
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['sanction OR unit OR state', '500', '500']
# Get initial docs: 0.5297427177429199
# Get precomputed embeddings: 0.017666101455688477
# Clean query: 0.0
# Embed query: 0.010155916213989258
# Score docs: 0.009696006774902344
# BERT rerank: 0.05359625816345215
# Get remaining data: 0.017949581146240234
# Get sponsors: 0.0
#
# Processing query 46: us sanctions
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['sanction OR us', '500', '500']
# Get initial docs: 0.3382225036621094
# Get precomputed embeddings: 0.019878625869750977
# Clean query: 0.0
# Embed query: 0.009710073471069336
# Score docs: 0.010049819946289062
# BERT rerank: 0.059737443923950195
# Get remaining data: 0.020085811614990234
# Get sponsors: 0.0
#
# Processing query 47: voter registration records and list maintenance
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['mainten OR voter OR registr OR list OR record', '500', '500']
# Get initial docs: 0.7672379016876221
# Get precomputed embeddings: 0.30825376510620117
# Clean query: 0.0
# Embed query: 0.020046710968017578
# Score docs: 0.011942386627197266
# BERT rerank: 0.35745716094970703
# Get remaining data: 0.1924116611480713
# Get sponsors: 0.0
#
# Processing query 48: voter registration records for federal election
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['voter OR feder OR elect OR registr OR record', '500', '500']
# Get initial docs: 0.9191558361053467
# Get precomputed embeddings: 0.09084224700927734
# Clean query: 0.0
# Embed query: 0.010840892791748047
# Score docs: 0.008255481719970703
# BERT rerank: 0.12282061576843262
# Get remaining data: 0.06026268005371094
# Get sponsors: 0.0
#
# Processing query 49: voter registration
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['voter OR registr', '500', '500']
# Get initial docs: 0.20624518394470215
# Get precomputed embeddings: 0.05149388313293457
# Clean query: 0.0
# Embed query: 0.02033257484436035
# Score docs: 0.00972604751586914
# BERT rerank: 0.09983992576599121
# Get remaining data: 0.031182527542114258
# Get sponsors: 0.0
#
# Processing query 50: workforce innovation and opportunity act of 2022
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['2022 OR act OR workforc OR opportun OR innov', '500', '500']
# Get initial docs: 1.258216142654419
# Get precomputed embeddings: 0.34009313583374023
# Clean query: 0.0
# Embed query: 0.009876728057861328
# Score docs: 0.010169506072998047
# BERT rerank: 0.37989091873168945
# Get remaining data: 0.19998645782470703
# Get sponsors: 0.0
#
# Processing query 51: workforce innovation and opportunity act
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['act OR innov OR workforc OR opportun', '500', '500']
# Get initial docs: 0.5228784084320068
# Get precomputed embeddings: 0.15716314315795898
# Clean query: 0.0
# Embed query: 0.01088261604309082
# Score docs: 0.008310317993164062
# BERT rerank: 0.1871025562286377
# Get remaining data: 0.0800163745880127
# Get sponsors: 0.0
#
# Processing query 52: workforce innovation and opportunity
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['innov OR workforc OR opportun', '500', '500']
# Get initial docs: 0.1678171157836914
# Get precomputed embeddings: 0.01711440086364746
# Clean query: 0.0
# Embed query: 0.010771036148071289
# Score docs: 0.009384393692016602
# BERT rerank: 0.05579662322998047
# Get remaining data: 0.021274566650390625
# Get sponsors: 0.0
#
# Processing query 53: workplace innovation
# select ft.id as id
#  from full_texts ft
#          join (
#             select ft_id, bm25(congress_bm25) as score
#             from congress_bm25
#             where congress_bm25 match ?
#             order by score
#             limit ?
#         ) as bm25_ft on ft.id = bm25_ft.ft_id
#  where ft.file_chamber = 'hr'
#  limit ?
# ['workplac OR innov', '500', '500']
# Get initial docs: 0.3779733180999756
# Get precomputed embeddings: 0.27998971939086914
# Clean query: 0.0
# Embed query: 0.01202249526977539
# Score docs: 0.00701451301574707
# BERT rerank: 0.3122904300689697
# Get remaining data: 0.12680983543395996
# Get sponsors: 0.0

# %%
import numpy as np

print('BERT MRR:', np.mean(bert_mrrs))
print('BERT P@50:', np.mean(bert_p50s))
print('BERT P@500:', np.mean(bert_p500s))
print('BERT R@50:', np.mean(bert_r50s))
print('BERT R@500:', np.mean(bert_r500s))
print('BERT MAP:', np.mean(bert_map))

print('\nCONGRESS MRR:', np.mean(congress_mrrs))
print('CONGRESS P@50:', np.mean(congress_p50s))
print('CONGRESS P@500:', np.mean(congress_p500s))
print('CONGRESS R@50:', np.mean(congress_r50s))
print('CONGRESS R@500:', np.mean(congress_r500s))
print('CONGRESS MAP:', np.mean(congress_map))
# Out:
# BERT MRR: 0.1614843050513482
# BERT P@50: 0.035
# BERT P@500: 0.01903846153846154
# BERT R@50: 0.14474621544378685
# BERT R@500: 0.4170194789573528
# BERT MAP: 0.04109991547255217
#
# CONGRESS MRR: 0.07289855045796147
# CONGRESS P@50: 0.03461538461538462
# CONGRESS P@500: 0.024653846153846155
# CONGRESS R@50: 0.1929614840788766
# CONGRESS R@500: 0.46625704698187226
# CONGRESS MAP: 0.05013851358506685
